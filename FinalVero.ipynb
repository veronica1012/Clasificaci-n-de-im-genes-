# %%
#Importacion de librerias
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Flatten, Dense
from keras.optimizers import SGD

# %%
#Cargamos imagenes de Train
imagenesTrainPathClase1="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_01"
imagenesTrainPathClase2="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_02"
imagenesTrainPathClase3="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_03"
imagenesTrainPathClase4="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_04"
imagenesTrainPathClase5="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_05"
imagenesTrainPathClase6="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_06"
imagenesTrainPathClase7="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_07"
imagenesTrainPathClase8="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/train/CLASS_08"
#ImagenesTrain=os.listdir(imagenesTrainPathClase1)+os.listdir(imagenesTrainPathClase2)

# %%
#Cargamos imagenes de Test
imagenesTestPathClase1="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_01"
imagenesTestPathClase2="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_02"
imagenesTestPathClase3="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_03"
imagenesTestPathClase4="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_04"
imagenesTestPathClase5="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_05"
imagenesTestPathClase6="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_06"
imagenesTestPathClase7="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_07"
imagenesTestPathClase8="D:/Maestria/Ciberseguridad/Modulo 2/Final/CarneDataset/test/CLASS_08"

# %%
#Carga de imagenes Clase 1
TrainClase1=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase1):
    img = cv2.imread(os.path.join(imagenesTrainPathClase1,img))
    #img_gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase1.append(img_resize)
    
TestClase1=[]
img_size=150
for img in os.listdir(imagenesTestPathClase1):
    img = cv2.imread(os.path.join(imagenesTestPathClase1,img))
    #img_gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase1.append(img_resize)

# %%
print(TrainClase1)
print(TestClase1)
# Out:
# []
# [array([[[183, 201, 176],
#         [183, 202, 176],
#         [183, 202, 177],
#         ...,
#         [171, 220, 204],
#         [200, 241, 225],
#         [207, 244, 227]],
#
#        [[179, 200, 175],
#         [180, 201, 176],
#         [181, 201, 177],
#         ...,
#         [163, 213, 196],
#         [199, 239, 224],
#         [206, 244, 227]],
#
#        [[176, 200, 175],
#         [177, 199, 174],
#         [180, 201, 177],
#         ...,
#         [154, 203, 189],
#         [195, 234, 219],
#         [207, 245, 227]],
#
#        ...,
#
#        [[ 90, 132, 131],
#         [ 90, 131, 131],
#         [ 92, 133, 134],
#         ...,
#         [149, 199, 210],
#         [193, 238, 240],
#         [235, 255, 248]],
#
#        [[ 91, 132, 131],
#         [ 92, 132, 132],
#         [ 92, 133, 134],
#         ...,
#         [177, 219, 219],
#         [229, 254, 249],
#         [232, 255, 245]],
#
#        [[ 91, 132, 131],
#         [ 93, 132, 132],
# ...

# %%
TrainClase2=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase2):
    img = cv2.imread(os.path.join(imagenesTrainPathClase2,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase2.append(img_resize)

TestClase2=[]
img_size=150
for img in os.listdir(imagenesTestPathClase2):
    img = cv2.imread(os.path.join(imagenesTestPathClase2,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase2.append(img_resize)

# %%
print(TrainClase2)
print(TestClase2)
# Out:
# [array([[[139, 199, 200],
#         [128, 186, 190],
#         [128, 183, 189],
#         ...,
#         [  0,   6,   3],
#         [  3,  15,  14],
#         [  0,   8,   5]],
#
#        [[128, 183, 188],
#         [127, 181, 187],
#         [127, 182, 188],
#         ...,
#         [  0,   7,   4],
#         [  6,  19,  17],
#         [  0,   6,   3]],
#
#        [[127, 180, 186],
#         [128, 181, 187],
#         [127, 181, 186],
#         ...,
#         [  0,   6,   5],
#         [  6,  14,  13],
#         [  0,   4,   3]],
#
#        ...,
#
#        [[ 71, 115, 145],
#         [ 66, 109, 140],
#         [ 66, 109, 138],
#         ...,
#         [ 16,  31,  49],
#         [ 27,  45,  72],
#         [ 25,  44,  69]],
#
#        [[ 72, 117, 145],
#         [ 70, 115, 143],
#         [ 71, 115, 144],
#         ...,
#         [ 26,  42,  68],
#         [ 16,  31,  48],
#         [ 22,  39,  63]],
#
#        [[ 74, 119, 144],
#         [ 74, 119, 145],
#         [ 76, 120, 147],
# ...

# %%
print(len(TrainClase2))
print(len(TestClase2))
# Out:
# 62
# 48

# %%
TrainClase2 = np.array(TrainClase2)
print(TrainClase2.shape)

TestClase2 = np.array(TestClase2)
print(TestClase2.shape)
# Out:
# (62, 150, 150, 3)
# (48, 150, 150, 3)

# %%
print(TrainClase2[3].shape)
plt.figure()
plt.imshow(np.squeeze(TrainClase2[3]))
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# (150, 150, 3)

# %%
TrainClase3=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase3):
    img = cv2.imread(os.path.join(imagenesTrainPathClase3,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase3.append(img_resize)

TestClase3=[]
img_size=150
for img in os.listdir(imagenesTestPathClase3):
    img = cv2.imread(os.path.join(imagenesTestPathClase3,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase3.append(img_resize)

# %%
#Se convierte a arreglo
TrainClase3 = np.array(TrainClase3)
print(TrainClase3.shape)

TestClase3 = np.array(TestClase3)
print(TestClase3.shape)
# Out:
# (213, 150, 150, 3)
# (97, 150, 150, 3)

# %%
TrainClase4=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase4):
    img = cv2.imread(os.path.join(imagenesTrainPathClase4,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase4.append(img_resize)

TestClase4=[]
img_size=150
for img in os.listdir(imagenesTestPathClase4):
    img = cv2.imread(os.path.join(imagenesTestPathClase4,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase4.append(img_resize)

# %%
#Se convierte a arreglo
TrainClase4 = np.array(TrainClase4)
print(TrainClase4.shape)

TestClase4 = np.array(TestClase4)
print(TestClase4.shape)
# Out:
# (105, 150, 150, 3)
# (45, 150, 150, 3)

# %%
TrainClase5=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase5):
    img = cv2.imread(os.path.join(imagenesTrainPathClase5,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase5.append(img_resize)
    
TestClase5=[]
img_size=150
for img in os.listdir(imagenesTestPathClase5):
    img = cv2.imread(os.path.join(imagenesTestPathClase5,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase5.append(img_resize)

# %%
#Se convierte a arreglo
TrainClase5 = np.array(TrainClase5)
print(TrainClase5.shape)

TestClase5 = np.array(TestClase5)
print(TestClase5.shape)
# Out:
# (949, 150, 150, 3)
# (459, 150, 150, 3)

# %%
TrainClase6=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase6):
    img = cv2.imread(os.path.join(imagenesTrainPathClase6,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase6.append(img_resize)

TestClase6=[]
img_size=150
for img in os.listdir(imagenesTestPathClase6):
    img = cv2.imread(os.path.join(imagenesTestPathClase6,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase6.append(img_resize)

# %%
#Se convierte a arreglo
TrainClase6 = np.array(TrainClase6)
print(TrainClase6.shape)

TestClase6 = np.array(TestClase6)
print(TestClase6.shape)
# Out:
# (37, 150, 150, 3)
# (19, 150, 150, 3)

# %%
TrainClase7=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase7):
    img = cv2.imread(os.path.join(imagenesTrainPathClase7,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase7.append(img_resize)

    
TestClase7=[]
img_size=150
for img in os.listdir(imagenesTestPathClase7):
    img = cv2.imread(os.path.join(imagenesTestPathClase7,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase7.append(img_resize)

# %%
#Se convierte a arreglo
TrainClase7 = np.array(TrainClase7)
print(TrainClase7.shape)

TestClase7 = np.array(TestClase7)
print(TestClase7.shape)
# Out:
# (204, 150, 150, 3)
# (114, 150, 150, 3)

# %%
TrainClase8=[]
img_size=150
for img in os.listdir(imagenesTrainPathClase8):
    img = cv2.imread(os.path.join(imagenesTrainPathClase8,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TrainClase8.append(img_resize)
    
TestClase8=[]
img_size=150
for img in os.listdir(imagenesTestPathClase8):
    img = cv2.imread(os.path.join(imagenesTestPathClase8,img))
    #img_gray= cv2.cvtColor(img,cv2.3)
    img_resize= cv2.resize(img,(img_size,img_size))
    TestClase8.append(img_resize)

# %%
#Se convierte a arreglo
TrainClase8 = np.array(TrainClase8)
print(TrainClase8.shape)

TestClase8 = np.array(TestClase8)
print(TestClase8.shape)
# Out:
# (63, 150, 150, 3)
# (27, 150, 150, 3)

# %%
#Concatenamos o unimos todas las categorias
images=np.concatenate([TrainClase2,TrainClase3,TrainClase4,TrainClase5,TrainClase6,TrainClase7,TrainClase8])
print(len(images))

imagestest=np.concatenate([TestClase2,TestClase3,TestClase4,TestClase5,TestClase6,TestClase7,TestClase8])
print(len(imagestest))
#Convertimos a un arreglo
Images=np.array(images)
print(Images.shape)

ImagesTest=np.array(imagestest)
print(ImagesTest.shape)
# Out:
# 1633
# 809
# (1633, 150, 150, 3)
# (809, 150, 150, 3)

# %%
#Etiquetas Categoria 1 se descarta
etiquetas_cat2=np.repeat(0,62) #se etiqueta con 2 y son 62 imagenes de categoria 2
etiquetas_cat3=np.repeat(1,213) #se etiqueta con 3 y son 213 imagenes de categoria 3
etiquetas_cat4=np.repeat(2,105) #se etiqueta con 4 y son 105 imagenes de categoria 4
etiquetas_cat5=np.repeat(3,949) #se etiqueta con 5 y son 949 imagenes de categoria 5
etiquetas_cat6=np.repeat(4,37) #se etiqueta con 6 y son 37 imagenes de categoria 6
etiquetas_cat7=np.repeat(5,204) #se etiqueta con 7 y son 204 imagenes de categoria 7
etiquetas_cat8=np.repeat(6,63) #se etiqueta con 8 y son 63 imagenes de categoria 8

# %%
categoria_nombres=['Categoria_2','Categoria_3','Categoria_4','Categoria_5','Categoria_6','Categoria_7','Categoria_8']
print(categoria_nombres[2])
# Out:
# Categoria_4

# %%
labels=np.concatenate([etiquetas_cat2,etiquetas_cat3,etiquetas_cat4,etiquetas_cat5,etiquetas_cat6,etiquetas_cat7,etiquetas_cat8])
print(len(labels))
LabelsTrain=np.array(labels)
print(LabelsTrain[2])
# Out:
# 1633
# 0

# %%
plt.figure(figsize=(10,10))
i=0
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(Images[i])
    #, cmap=plt.cm.binary
    plt.xlabel(categoria_nombres[LabelsTrain[i]])
plt.show()

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

variable_name = ""
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

from __future__ import absolute_import, division, print_function, unicode_literals


# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import tensorflow.keras.optimizers as Optimizer

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.9.2

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(150, 150,3)),
    keras.layers.Dense(128, activation='relu'),
    
    keras.layers.Dense(7, activation='softmax'),
    
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(Images, LabelsTrain, epochs=30)
trained=model.fit(Images, LabelsTrain, epochs=30)
# Out:
# Epoch 1/30
# 52/52 [==============================] - 2s 29ms/step - loss: 3665.7146 - accuracy: 0.4532
# Epoch 2/30
# 52/52 [==============================] - 1s 28ms/step - loss: 164.5644 - accuracy: 0.5462
# Epoch 3/30
# 52/52 [==============================] - 2s 32ms/step - loss: 12.3490 - accuracy: 0.3974
# Epoch 4/30
# 52/52 [==============================] - 2s 30ms/step - loss: 1.8905 - accuracy: 0.5811
# Epoch 5/30
# 52/52 [==============================] - 1s 28ms/step - loss: 1.8491 - accuracy: 0.5811
# Epoch 6/30
# 52/52 [==============================] - 2s 29ms/step - loss: 1.8108 - accuracy: 0.5811
# Epoch 7/30
# 52/52 [==============================] - 2s 31ms/step - loss: 1.7751 - accuracy: 0.5811
# Epoch 8/30
# 52/52 [==============================] - 1s 29ms/step - loss: 1.7415 - accuracy: 0.5811
# Epoch 9/30
# 52/52 [==============================] - 1s 29ms/step - loss: 1.7099 - accuracy: 0.5811
# Epoch 10/30
# ...

# %%
#Tomamos los datos de test
img=ImagesTest[1]
print(img.shape)
img=(np.expand_dims(img,0))
print(img.shape)
# Out:
# (150, 150, 3)
# (1, 150, 150, 3)

# %%
plt.figure()
plt.imshow(ImagesTest[100])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
prediccion=model.predict(img)
print(prediccion)
print(np.argmax(prediccion))
print(categoria_nombres[np.argmax(prediccion)])
# Out:
# 1/1 [==============================] - 0s 41ms/step
# [[0.0432503  0.12459929 0.06357449 0.5742537  0.03006486 0.12226076
#   0.04199663]]
# 3
# Categoria_5

# %%
from sklearn.metrics import confusion_matrix
#Predict
y_prediction = model.predict(img)
y_prediction = np.argmax (y_prediction, axis = 1)
y_test=np.argmax(ImagesTest, axis=1)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_test, y_prediction , normalize='pred')
print(result)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-ed35c9a420c3> in <module>
#       5 y_test=np.argmax(ImagesTest, axis=1)
#       6 #Create confusion matrix and normalizes it over predicted (columns)
# ----> 7 result = confusion_matrix(y_test, y_prediction , normalize='pred')
#       8 print(result)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     294
#     295     """
# ...
